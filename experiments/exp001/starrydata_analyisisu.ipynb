# %%
import pandas as pd

# %%
import pandas as pd

path = r"C:\Users\miots\OneDrive - 山陽小野田市立山口東京理科大学 (1)\USBにいたヤツ\大学\2025\研究\starrydata2\starrydata_curves.csv"

df = pd.read_csv(path)

# %%
df.head()
# Out:
#     SID                            DOI                   composition  \
# 0     6              10.1021/am405410e  Pb1.00025Zn0.02Te1.02I0.0005
# 1  6006         10.1002/adma.201004200           Na0.0035Pb0.9965Se1
# 2  6444         10.1002/anie.200803934               Pb1.03Sb0.03Te1
# 3  5867  10.1016/j.actamat.2016.03.059         Pb0.76Mn0.24Te1Na0.04
# 4  3485              10.1021/ja109138p       Pb1S0.84Te0.16Cl0.00134
#
#    sample_id  figure_id       prop_x               prop_y unit_x    unit_y  \
# 0        113         79  Temperature  Seebeck coefficient      K  V*K^(-1)
# 1        147         80  Temperature  Seebeck coefficient      K  V*K^(-1)
# 2        434         81  Temperature  Seebeck coefficient      K  V*K^(-1)
# 3        248         83  Temperature  Seebeck coefficient      K  V*K^(-1)
# 4        389         84  Temperature  Seebeck coefficient      K  V*K^(-1)
#
#                                                    x  \
# ...

# %% [markdown]
# C:\Users\miots\OneDrive - 山陽小野田市立山口東京理科大学 (1)\USBにいたヤツ\大学\2025\研究\starrydata2\starrydata_curves.csv
